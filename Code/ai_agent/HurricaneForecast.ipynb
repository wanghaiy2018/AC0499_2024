# %%
import requests
import json
import re  # Import the re module for regular expressions

# Class to interact with the Llama model server
class LlamaLLM:
    def __init__(self, url):
        self.url = url
        self.call_count = 0

    def generate(self, prompt):
        self.call_count += 1
        payload = {
            "model": "llama3.1",
            "prompt": prompt,
            "stream": False
        }
        headers = {
            'Content-Type': 'application/json'
        }
        response = requests.post(self.url, headers=headers, data=json.dumps(payload))
        response.raise_for_status()
        return response.json()['response']

# Environment class for hurricane forecasting
class HurricaneEnvironment:
    def __init__(self, hurricane_data):
        self.state = 'initial_state'
        self.goal_achieved = False
        self.result = None
        self.hurricane_data = hurricane_data

    def get_state(self):
        return self.state

    def change_state(self, result):
        self.state = 'goal_state'
        self.result = result

# HurricaneForecastAgent class for hurricane forecasting
class HurricaneForecastAgent:
    def __init__(self, environment, llm, max_attempts=5):
        self.environment = environment
        self.llm = llm
        self.max_attempts = max_attempts

    def perceive(self):
        return self.environment.get_state()

    def reason(self, state):
        prompt = self.create_prompt(self.environment.hurricane_data)
        response = self.llm.generate(prompt).strip()
        print(f"Raw Llama Response: {response}")  # Debugging: print raw response
        decision = self.extract_forecast(response)
        return 'achieve_goal' if decision else 'take_action', decision

    def act(self, action, result):
        if action == 'achieve_goal':
            self.environment.goal_achieved = True
            self.environment.change_state(result)

    def create_prompt(self, hurricane_data):
        prompt = f"""
        The hurricane data is as follows:
        Historical Data: {hurricane_data['historical_data']}
        Current Observations: {hurricane_data['current_observations']}
        Model Predictions: {hurricane_data['model_predictions']}
        Given this information, what is the most likely path and impact of the hurricane?
        """
        return prompt

    def extract_forecast(self, response):
        # Extracts a forecast from the Llama model's response
        # Assuming the response contains a clear path prediction
        path_pattern = re.compile(r'landfall in (.*?)(?:,|\.| )', re.IGNORECASE)
        match = path_pattern.search(response)
        return match.group(1) if match else None

# Example hurricane data
hurricane_data = {
    "historical_data": "Data from previous hurricanes including paths, intensities, and impacts.",
    "current_observations": "Current satellite images, ocean buoy data, and radar data.",
    "model_predictions": "Predictions from various models like the European Center for Medium-Range Weather Forecasts and the National Hurricane Center."
}

# Initialize the Llama model with the server URL
llm = LlamaLLM(url="http://localhost:11434/api/generate")

# Create environment and agent
env = HurricaneEnvironment(hurricane_data)
agent = HurricaneForecastAgent(env, llm)

# Agent perception, reasoning, and action loop
attempts = 0
while not env.goal_achieved and attempts < agent.max_attempts:
    state = agent.perceive()
    action, result = agent.reason(state)
    agent.act(action, result)
    attempts += 1
    print(f"State: {state}, Action: {action}, Result: {result}, Attempts: {attempts}")

if env.goal_achieved:
    print(f"Goal achieved with result: {env.result}")
else:
    print("Failed to achieve goal within the maximum number of attempts.")
# Out:
# Raw Llama Response: Given the provided historical data, current observations, and model predictions, a detailed analysis would be necessary to determine the most likely path and impact of the hurricane. However, here’s a simplified approach based on typical steps meteorologists follow for such assessments:
#
# ### 1. Historical Data Review
# - **Trends and Patterns**: Look for patterns in hurricane paths over the years for the region affected.
# - **Previous Storms**: Understand how storms of similar intensity and category have behaved historically.
#
# ### 2. Current Observations
# - **Weather Conditions**: Analyze current satellite images, ocean buoy data, and radar to understand wind speed, direction, sea levels, atmospheric conditions, etc., which influence storm paths and intensities.
# - **Real-time Data**: These observations are crucial for updating predictions in real time.
#
# ### 3. Model Predictions
# - **Multiple Models**: Use outputs from several models to average out discrepancies and predict a more probable scenario.
# - **Uncertainty Level**: Understand the level of uncertainty associated with each model's prediction, as some may be more accurate than others under certain conditions.
#
# ### 4. Integration and Analysis
# - **Combine Data**: Integrate historical data, current observations, and model predictions to make an informed forecast.
# - **Sensitivity Analysis**: Consider the sensitivity of outcomes to changes in initial conditions or models used.
# - **Human Expertise**: Incorporate experienced meteorologists' insights based on their understanding of weather patterns and storm behavior.
#
# ### 5. Final Prediction
# - **Best Estimate**: Based on integrated data, provide a best estimate for the path and impact of the hurricane.
# - **Uncertainty Statement**: Clearly communicate any uncertainty or range within which the prediction may fall.
#
# Given the detailed nature of these steps, making accurate predictions is challenging but crucial for planning and safety measures.
# State: initial_state, Action: take_action, Result: None, Attempts: 1
# Raw Llama Response: To provide an accurate assessment of the hurricane's most likely path and potential impacts, I'll walk you through a structured analysis combining historical data, current observations, and model predictions.
#
# ### 1. Historical Data Analysis
# Historical data from previous hurricanes provides valuable insights into typical paths, intensities, and impacts. For example:
# - **Path Tendencies:** Analyze the general direction hurricanes tend to take in your region or similar regions.
# - **Intensity Variability:** Understand the range of intensity hurricanes can reach in the area you're concerned about.
# - **Impact Types:** Determine the types of damage hurricanes have historically caused (storm surges, flooding, wind damage).
#
# ### 2. Current Observations Review
# Reviewing current satellite images, ocean buoy data, and radar data gives an immediate snapshot of the situation:
# - **Satellite Images:** Show the storm's size, intensity, and movement direction.
# - **Ocean Buoy Data:** Can indicate sea surface temperatures which influence hurricane strength and longevity.
# - **Radar Data:** Offers detailed information on wind speed and direction around the storm.
#
# ### 3. Model Predictions Analysis
# Evaluating predictions from reliable models like the European Center for Medium-Range Weather Forecasts (ECMWF) and the National Hurricane Center (NHC):
# - **Path Predictions:** Look at where these models are forecasting the hurricane to go.
# - **Intensity Projections:** Determine if they predict the storm will strengthen, weaken, or remain steady in intensity.
# - **Impact Zones:** Understand which areas they predict will be most affected by wind, rain, and potential storm surges.
#
# ### Synthesizing the Data
# After analyzing each type of data, synthesizing them is crucial:
# - **Look for Consistency:** If multiple lines of evidence agree on a path or impact, that's more likely to happen.
# - **Consider Uncertainty:** Even with good information, there are always uncertainties. These can come from model inaccuracies or unforeseen weather patterns.
# - **Prepare for the Worst:** Given the potential impacts, make sure to take necessary precautions and have contingency plans in place.
#
# ### Conclusion
# The most likely path and impact of a hurricane can be estimated by combining historical data with current observations and model predictions. This approach offers a balanced view that takes into account various factors influencing weather patterns.
# State: initial_state, Action: take_action, Result: None, Attempts: 2
# Raw Llama Response: Based on the provided historical data, current observations, and model predictions, I'll attempt to provide a hypothetical forecast. Keep in mind that actual weather forecasting involves complex models and human interpretation, and this response should not be taken as an official forecast.
#
# **Historical Data:**
# The historical hurricane data shows that hurricanes tend to follow predictable patterns:
#
# 1. Hurricanes often form over warm ocean waters (above 26.5°C/80°F) and move westward due to the trade winds.
# 2. They can intensify or weaken based on factors like wind shear, dry air, and interaction with other weather systems.
#
# **Current Observations:**
#
# 1. Satellite images show a low-pressure system forming over warm ocean waters in the Atlantic, indicating potential hurricane development.
# 2. Ocean buoy data indicates sea surface temperatures are above 28°C (82°F), suggesting favorable conditions for intensification.
# 3. Radar data shows that the storm is moving westward at approximately 10-15 km/h (6-9 mph).
#
# **Model Predictions:**
#
# 1. The European Center for Medium-Range Weather Forecasts (ECMWF) model predicts a high likelihood of hurricane formation, with a 90% probability.
# 2. The National Hurricane Center's (NHC) model suggests the storm will intensify to a Category 3 hurricane within the next 48 hours.
#
# Considering these factors, here is my hypothetical forecast:
#
# **Most Likely Path:**
# The storm is expected to continue moving westward at approximately 10-15 km/h (6-9 mph). It may pass near or over the Lesser Antilles islands and then head towards the Caribbean Sea. The track will be influenced by wind shear and interaction with other weather systems, but based on current conditions, a northwesterly trajectory is likely.
#
# **Most Likely Impact:**
# Given its expected intensity (Category 3 hurricane), I predict:
#
# 1. Strong winds of up to 200 km/h (125 mph) and heavy rainfall will affect the Lesser Antilles islands.
# 2. The storm surge could reach up to 4 meters (13 feet) in some areas, causing coastal flooding and damage.
# 3. The impact on land is expected to be significant, with potential power outages, property damage, and displacement of people.
#
# Please note that this forecast is hypothetical and based solely on the provided information. Actual weather forecasting involves complex models, data interpretation, and human expertise, which cannot be replicated in a short answer like this. Always rely on official forecasts from trusted sources like the National Hurricane Center (NHC) or your local meteorological agency for accurate and up-to-date information.
# State: initial_state, Action: take_action, Result: None, Attempts: 3
# Raw Llama Response: A complex forecasting problem!
#
# To determine the most likely path and impact of the hurricane, we can consider a combination of the available data. Here's a step-by-step approach:
#
# **Step 1: Review Historical Data**
#
# Analyze past hurricanes with similar characteristics (e.g., same storm type, season, and region) to identify any patterns or trends in their paths and impacts.
#
# **Step 2: Analyze Current Observations**
#
# Examine current satellite images, ocean buoy data, and radar data for signs of the hurricane's current position, intensity, and movement. This will help determine its current state and trajectory.
#
# **Step 3: Evaluate Model Predictions**
#
# Consider predictions from multiple models (e.g., European Center for Medium-Range Weather Forecasts, National Hurricane Center) to estimate potential future paths and intensities. Look for consistency across different models and account for their respective uncertainties.
#
# **Integration of Data**
#
# Combine the insights from historical data, current observations, and model predictions to create a comprehensive understanding of the hurricane's likely path and impact.
#
# **Likely Path:**
#
# Based on the analysis:
#
# * If the historical data suggests a consistent pattern of hurricanes moving in a particular direction (e.g., westward) and the current observations indicate a strong wind field with a similar orientation, it is likely that the storm will continue to move in that general direction.
# * Model predictions that consistently show the hurricane maintaining its intensity or intensifying further would support this conclusion.
#
# **Likely Impact:**
#
# Considering the likely path:
#
# * If the storm is predicted to maintain its intensity or strengthen, areas directly in its path may experience significant damage from wind and rain. This could include coastal communities, agricultural regions, and other sensitive ecosystems.
# * The extent of the impact will depend on factors like population density, infrastructure vulnerability, and emergency preparedness.
#
# **Uncertainty and Adjustments:**
#
# Keep in mind that even with a comprehensive analysis, there is always some degree of uncertainty when predicting hurricane behavior. Monitor updates from trusted sources (e.g., National Weather Service, local authorities) to adjust forecasts and plan for potential changes in the storm's path or intensity.
#
# Remember, forecasting hurricanes is a complex task that requires careful consideration of multiple factors. This approach will provide a solid foundation for estimating the most likely path and impact of a hurricane.
# State: initial_state, Action: take_action, Result: None, Attempts: 4
